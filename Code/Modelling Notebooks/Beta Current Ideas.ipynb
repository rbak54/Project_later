# %% [markdown]
# set of beta ideas ( 4 is the one used in later notebooks)

# %% [markdown]
# # Altering Beta

# %% [markdown]
# Detail of Valle 2013 model and potential modifications I am considering. Modification is most similar to Valle but harder to parameterise. Modification is fairly mechanistic (but similar to modification 2 and 3), but struggling to convert into a proportion

# %% [markdown]
# ## Valle 2013
# Simplified from an spatially and age structured model
# Force of Infection:
# $\delta=$ number of contacts per unit time X probability of disease transmission per contact X proportion of contacts that are infected
# $\delta= c_r   \times  \epsilon \times \tau \times  (1-e^{-\zeta d}) \times \frac{I}{N}$
#
# $[1-e^{\zeta d}]=[1]-e^{[{time/time}]}=$unitless
# $[\delta]=[c_r]$=individual/(individual x day)
#
#
# Transmissibility:
# $\beta = c_r   \times  \epsilon \times \tau \times  (1-e^{-\zeta d}) $
# $\beta=$ number of contacts per unit time X probability of disease transmission per contact
# $[\beta]=[c_r]=$individual/(individual x day)
# ##### Parameters
# I have assumed that day is the unit of time here.
#
# $c_r$ is contact rate per day  (individuals/(individual x day)
# $\epsilon$ is infectivity of infective
# $\tau$ is the susceptibility of the susceptible.
# $\zeta$ is the number of transmission events per unit time (1/day)
# d is average contact duration of a contact (days)
# S is no of susceptibles  (individuals)
# I is no of infectives     (individuals)
# N is pop size (individuals)
#
# $\epsilon \times \tau \times  (1-e^{-\zeta d})$: probability of disease transmission per contact between I and S.
# $(1-e^{-\zeta d})$: probability of transmission based on the average duration of contacts. scaled between 0 and 1.
#
#
#
# )

# %% [markdown]
# ## Modifications 1
# ##### Changes
# I have ignored susceptibility of susceptible ($\tau$) as my model does not have age structure and there is not likely to be residual immunity
# I have removed the age and spatial structure
# I have kept $\epsilon$ in for now. It would make sense that there is a maximum possibly infectivity (not 100% of contacts will cause infection.
#
# ##### Equations
# $\beta = c_r   \times  \epsilon \times  (1-e^{-\zeta d}) $
# $\beta=$ number of contacts per unit time X probability of disease transmission per contact
# $[\beta]=[c_r]=$individual/(individual x day)
#
# $[1-e^{-\zeta d}]=[1]-e^{[{time/time}]}=$unitless
# $[\beta]=[c_r]=$individual/(individual x day)
#
# ##### Parameters
# I have assumed that day is the unit of time here.
# $c_r$ is contact rate per day  (individuals/(individual x day)
# $\epsilon$ is infectivity of infective
# $\tau$ is the susceptibility of the susceptible.
# $\zeta$ is the number of transmission events per unit time (1/day)
# d is average contact duration of a contact (days)
# S is no of susceptibles  (individuals)
# I is no of infectives     (individuals)
# N is pop size (individuals)
#
# ##### plan with climate:
# social behaviour- d, c_R could be socially affected by climate
# $zeta$ could be physiologically affected by climate

# %% [markdown]
# ## Modifications 2
# I have ignored susceptibility of susceptible ($\tau$) as my model does not have age structure and there is not likely to be residual immunity
# I have removed the age and spatial structure
# I have kept $\epsilon$ in for now. It would make sense that there is a maximum possibly infectivity (not 100% of contacts will cause infection.
#
# Trying to convert $\zeta$ to depend on s:
# Replace $(1-e^{-\zeta d})$ with $(1-e^{-(1-\frac{s}{min(s)})\zeta d})$
# - scale s to between 0 and 1.-$\frac{s}{min(s)}$
# - (When s decreases, decay will happen quicker, so $\beta$ will be lower.(This is the case when $e^x$  is higher so the exponent needs to be less negative, so s needs to be scaled closer to 0 $(1- \frac{s}{min(s)}$ )
# - (When s increases (becomes closer to 0), decay will happen slower, so $\beta$ should be higher . (This is the case when $e^x$  is low so the exponent needs to be more negative, so s needs to be scaled closer to 1 $(1- \frac{s}{min(s)}$ )
# - multiply this by $\zeta$. so scaling between 0 and maximum $zeta$
# - this is less than ideal because requires being able to estimate maximum $\zeta$ and s is no longer meaningful
#
#
# ##### Equations
# $\beta = c_r  \times  \epsilon \times  (1-e^{-(1-\frac{s}{min(s)})\zeta d})$
# $\beta=$ number of contacts per unit time X probability of disease transmission per contact
#
#
# $[1-e^{-(1-\frac{s}{min(s)})\zeta d}]=[1]-e^{-(([1]-[\frac{1/time}{1/time}])[\zeta d])}=[1]-e^{-[\zeta d]}=$unitless
# $[\beta]=[c_r]=$individual/(individual x day)
#
#
# ##### Parameters
# I have assumed that day is the unit of time here.
# $c_r$ is contact rate per day  (individuals/(individual x day)
# $\epsilon$ is infectivity of infective
# $\tau$ is the susceptibility of the susceptible.
# $\zeta$ is the number of transmission events per unit time (1/day)
# d is average contact duration of a contact (days)
# S is no of susceptibles  (individuals)
# I is no of infectives     (individuals)
# N is pop size (individuals)
# s is the growth rate of the virus (negative) (1/time)
#
#
# ##### plan with climate:
# social behaviour- d, c_R could be socially affected by climate
# $s$ physiologically affected by climate

# %% [markdown]
# ## Modifications 3
# ##### Changes
# I have ignored susceptibility of susceptible ($\tau$) as my model does not have age structure and there is not likely to be residual immunity
# I have removed the age and spatial structure
# I have kept $\epsilon$ in for now. It would make sense that there is a maximum possibly infectivity (not 100% of contacts will cause infection.
#
#
# The aim here is to convert $\zeta$ into something s dependent. I don't think there is enough information available to do this mechanistically  (should I look into this??)
# Again this approach loses the biological meaning of s.
# - make s positive by added minimum s to all.(s-(min(s))
# - replace $\zeta$ with constant l x (s-min(s))
#
#
# ##### Equations
# $\beta = c_r   \times  \epsilon \times  (1-e^{-(s-min(s)) d}) $
# $\beta=$ number of contacts per unit time x probability of disease transmission per contact
#
# $[1-e^{-(s-min(s)) d}]=[1]-e^{[-(s-min(s)) d]}==[1]-e^{[-time/time]}=$unitless
# $[\beta]=[c_r]=$individual/(individual x day)
#
# ##### Parameters
# I have assumed that day is the unit of time here.
# $c_r$ is contact rate per day  (individuals/(individual x day)
# $\epsilon$ is infectivity of infective
# $\tau$ is the susceptibility of the susceptible.
# $\zeta$ iModificationss the number of transmission events per unit time (1/day)
# d is average contact duration of a contact (days)
# S is no of susceptibles  (individuals)
# I is no of infectives     (individuals)
# N is pop size (individuals)
#
#
# ##### plan with climate:
# social behaviour- d, c_R could be socially affected by climate
# $s$ physiologically affected by climate

# %% [markdown]
# ## Modifications 4
# ##### Changes
# I have ignored susceptibility of susceptible ($\tau$) as my model does not have age structure and there is not likely to be residual immunity
# I have removed the age and spatial structure
# I have kept $\epsilon$ in for now. It would make sense that there is a maximum possibly infectivity (not 100% of contacts will cause infection.
#
#
# The aim here is to find expected viral titre at time duration d if shedding occurs at rate a, then convert this into a (dimensionless) probability of infection. probability needs:
# - to increase as d increases( as contact longer, infection more likely)
# - to decreases as rate of decay increases (i.e s(growth rate) gets lower)(or b (rate of decay)=-s increases)
# - option 4 is the only time this works!
#
#
# ##### Equations
#
# $\frac{dV}{dd}=a-bV$
# $[\frac{dV}{dd}] =titre/(time x individual)-\frac { titre}{individual}\frac{1}{time}=titre/(individual  x time)$
# $V=\frac{a}{b}+ce^{-bd}$
# $[V]=\frac { titre}{time  x  individual}/ \frac{1}{time}+[c]e^{time/time}=\frac{titre}{individual}$
# units of c must be titre/individual
#
#
# initially t=0, V = 0:
# - $V=\frac{a}{b}+ce^{-b0}=0$
# - $-\frac{a}{b}=c$
#
# $V=\frac{a}{b}+-\frac{a}{b}e^{-bd}=\frac{a}{b}(1-e^{-bd})$
# Need to scale this between 0 and 1 to get a probability of transmission
#
#
#
# $\beta = c_r   \times  \epsilon \times  probability $
# $\beta=$ number of contacts per unit time x probability of disease transmission per contact
#
#
#
#
# $[\beta]=[c_r]=$individual/(individual x day)
# ###### Find probabiity- stuck here
#
# option 1:
# michaelis menten, monod or holling??
# $\frac{[S]}{K_m + [S]}$
# probability= $\frac{\frac{a}{b}(1-e^{-bd})}{\frac{a}{b}(1-e^{-bd})-\frac{ln(0.5)}{b}}$ kind of works but units don't and b goes in wrong direction
#
# option 2 :
#
# $V=\frac{a}{b}-\frac{a}{b}e^{-bd}$
# $\frac{V}{max(V)}=\frac{\frac{a}{b}-\frac{a}{b}e^{-bd}}{\frac{a}{b}}=1-e^{-bd}$
# $1-\frac{V}{max(V)}=1-(1-e^{-bt})=e^{-bt}$  now t goes in the wrong direction!
#
#
# option 3 :
# ?$probability=\frac{(\frac{a}{b}(1-e^{-bd}))}{\frac{a}{b}(1-e^{-bd})+1}$ but units don't make sense
#
# ?$probability=\frac{\frac{a}{b}(1-e^{-bd})}{h\frac{a}{b}(1-e^{-bd})+a}=\frac{\frac{1}{b}(1-e^{-bd})}{h\frac{1}{b}(1-e^{-bd})+1}$ The units here are incorrect (although this is most similar to functional response and I quite like the shape)
#
# option 4: BEST
# $probability=\frac{\frac{a}{b}(1-e^{-bd})}{\frac{a}{b}(1-e^{-bd})+ah}=\frac{\frac{1}{b}(1-e^{-bd})}{\frac{1}{b}(1-e^{-bd})+h}$
#
# ah is the amount of virus shed in the time needed for transmission to occur
# $[probability]=\frac{\frac{titre/(individual x time)}{1/time} [1-e^{-time/time}]}{\frac{titre/(individual x time)}{1/time} [1-e^{-time/time}]+[time x titre/(individual x time) ]}=\frac{titre/(individual x time)x time [1-e^{[-1]}]}{titre/(individual x time)x time [1-e^{[-1]}]+titre/(individual) }=\frac{titre/(individual)}{titre/(individual) +titre/(individual)}=unitless$
#
#
#
# If use option 4, overall equation is
# $\beta = c_r   \times  \epsilon \times  \frac{\frac{1}{b}(1-e^{-bd})}{\frac{1}{b}(1-e^{-bd})+h} $
# $\beta=$ number contacts per unit time x probability of disease transmission per contact
#
#
#
#
# $[\beta]=[c_r]=individual/(individual x day) \times unitless $
#
# ##### Parameters
# I have assumed that day is the unit of time here.
# $c_r$ is contact rate per day  (individuals/(individual x day)
# $\epsilon$ is infectivity of infective
# $\tau$ is the susceptibility of the susceptible.
# $\zeta$ is the number of transmission events per unit time (1/day)
# d is average contact duration of a contact (days)
# S is no of susceptibles  (individuals)
# I is no of infectives     (individuals)
# N is pop size (individuals)
# V is the net amount of virus per individual shedding (titre/individual)
# a is the amount of virus shed per individual per unit time (titre/(time x individual)
# b is the rate of decay of the virus (1/time)
# h is the expected duration of contact needed for tramsmission (time)
#
# ##### plan with climate:
# social behaviour- d, c_R could be socially affected by climate
# $s$ physiologically affected by climate

# %%
?abline

# %% [markdown]
# # Best Option 4.4:
# $probability=\frac{\frac{a}{b}(1-e^{-bd})}{\frac{a}{b}(1-e^{-bd})+ah}=\frac{\frac{1}{b}(1-e^{-bd})}{\frac{1}{b}(1-e^{-bd})+h}$
#
# ah is the amount of virus shed in the time needed for transmission to occur
# $[probability]=\frac{\frac{titre/(individual x time)}{1/time} [1-e^{-time/time}]}{\frac{titre/(individual x time)}{1/time} [1-e^{-time/time}]+[time x titre/(individual x time) ]}=\frac{titre/(individual x time)x time [1-e^{[-1]}]}{titre/(individual x time)x time [1-e^{[-1]}]+titre/(individual) }=\frac{titre/(individual)}{titre/(individual) +titre/(individual)}=unitless$
#
#
#
# If use option 4, overall equation is
# $\beta = c_r   \times  \epsilon \times  \frac{\frac{1}{b}(1-e^{-bd})}{\frac{1}{b}(1-e^{-bd})+h} $
# $\beta=$ number contacts per unit time x probability of disease transmission per contact
#
#
#
#
# $[\beta]=[c_r]=individual/(individual x day) \times unitless $
#
# ##### Parameters
# I have assumed that day is the unit of time here.
# $c_r$ is contact rate per day  (individuals/(individual x day)
# $\epsilon$ is infectivity of infective
# $\tau$ is the susceptibility of the susceptible.
# $\zeta$ is the number of transmission events per unit time (1/day)
# d is average contact duration of a contact (days)
# S is no of susceptibles  (individuals)
# I is no of infectives     (individuals)
# N is pop size (individuals)
# V is the net amount of virus per individual shedding (titre/individual)
# a is the amount of virus shed per individual per unit time (titre/(time x individual)
# b is the rate of decay of the virus (1/time)
# h is the expected duration of contact needed for tramsmission (time)
#
# ##### plan with climate:
# social behaviour- d, c_R could be socially affected by climate
# $s$ physiologically affected by climate
